# %%
# Import the dependencies.
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
import random
from citipy import citipy
from datetime import datetime 
from config import weather_api_key
import requests
import time
from scipy.stats import linregress
import gmaps
from config import g_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 781

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

    # Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_city = city.title()
        city_country = city_weather['sys']['country']
        city_date = datetime.utcfromtimestamp(city_weather['dt']).strftime('%Y-%m-%d %H:%M:%S')
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_hum = city_weather['main']['humidity']
        city_cloud = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_desc = city_weather['weather'][0]['description']

        # Fill City Data list 
        city_data.append({"City": city_city,
                         "Country": city_country,
                         "Date": city_date,
                         "Lat": city_lat,
                         "Lng": city_lng,
                         "Max Temp": city_max_temp,
                         "Humidity": city_hum,
                         "Cloudiness": city_cloud,
                         "Wind Speed": city_wind,
                         "Current Description": city_desc,
                         })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | tasiilaq
# Processing Record 2 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 3 of Set 1 | louis trichardt
# Processing Record 4 of Set 1 | ponta do sol
# Processing Record 5 of Set 1 | mahadday weyne
# City not found. Skipping...
# Processing Record 6 of Set 1 | manzhouli
# Processing Record 7 of Set 1 | lagoa
# Processing Record 8 of Set 1 | brewster
# Processing Record 9 of Set 1 | avera
# Processing Record 10 of Set 1 | anuradhapura
# Processing Record 11 of Set 1 | vagamo
# Processing Record 12 of Set 1 | trairi
# Processing Record 13 of Set 1 | yumen
# Processing Record 14 of Set 1 | yellowknife
# Processing Record 15 of Set 1 | abnub
# Processing Record 16 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 17 of Set 1 | bluff
# Processing Record 18 of Set 1 | punta arenas
# Processing Record 19 of Set 1 | constitucion
# Processing Record 20 of Set 1 | irbeyskoye
# Processing Record 21 of Set 1 | haukipudas
# Processing Record 22 of Set 1 | atuona
# Processing Record 23 of Set 1 | nouakchott
# Processing Record 24 of Set 1 | vieste
# Processing Record 25 of Set 1 | kaiyuan
# Processing Record 26 of Set 1 | haibowan
# City not found. Skipping...
# Processing Record 27 of Set 1 | castel san giovanni
# Processing Record 28 of Set 1 | khani
# Processing Record 29 of Set 1 | chicama
# Processing Record 30 of Set 1 | nara
# Processing Record 31 of Set 1 | tunceli
# Processing Record 32 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 33 of Set 1 | soyo
# Processing Record 34 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 35 of Set 1 | johi
# Processing Record 36 of Set 1 | sur
# Processing Record 37 of Set 1 | aberdeen
# Processing Record 38 of Set 1 | barrow
# Processing Record 39 of Set 1 | pimentel
# Processing Record 40 of Set 1 | port alfred
# Processing Record 41 of Set 1 | airai
# Processing Record 42 of Set 1 | ushuaia
# Processing Record 43 of Set 1 | chokurdakh
# Processing Record 44 of Set 1 | hirara
# Processing Record 45 of Set 1 | rikitea
# Processing Record 46 of Set 1 | lebu
# Processing Record 47 of Set 1 | hermanus
# Processing Record 48 of Set 1 | tuktoyaktuk
# Processing Record 49 of Set 1 | vaini
# Processing Record 50 of Set 1 | vanimo
# Processing Record 1 of Set 2 | albany
# Processing Record 2 of Set 2 | kupang
# Processing Record 3 of Set 2 | narsaq
# Processing Record 4 of Set 2 | pisco
# Processing Record 5 of Set 2 | bonavista
# Processing Record 6 of Set 2 | cidreira
# Processing Record 7 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 8 of Set 2 | artyk
# City not found. Skipping...
# Processing Record 9 of Set 2 | ancud
# Processing Record 10 of Set 2 | mataura
# Processing Record 11 of Set 2 | paamiut
# Processing Record 12 of Set 2 | la ronge
# Processing Record 13 of Set 2 | punganuru
# Processing Record 14 of Set 2 | moose factory
# Processing Record 15 of Set 2 | dikson
# Processing Record 16 of Set 2 | mingaora
# Processing Record 17 of Set 2 | jamestown
# Processing Record 18 of Set 2 | saint-pierre
# Processing Record 19 of Set 2 | saint-philippe
# Processing Record 20 of Set 2 | luderitz
# Processing Record 21 of Set 2 | manono
# Processing Record 22 of Set 2 | oranjemund
# Processing Record 23 of Set 2 | roros
# Processing Record 24 of Set 2 | east london
# Processing Record 25 of Set 2 | qaanaaq
# Processing Record 26 of Set 2 | butaritari
# Processing Record 27 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 28 of Set 2 | kruisfontein
# Processing Record 29 of Set 2 | sayat
# Processing Record 30 of Set 2 | vardo
# Processing Record 31 of Set 2 | victoria
# Processing Record 32 of Set 2 | boyolangu
# Processing Record 33 of Set 2 | lompoc
# Processing Record 34 of Set 2 | half moon bay
# Processing Record 35 of Set 2 | kapaa
# Processing Record 36 of Set 2 | cayenne
# Processing Record 37 of Set 2 | goya
# Processing Record 38 of Set 2 | kinsale
# Processing Record 39 of Set 2 | saint-augustin
# Processing Record 40 of Set 2 | agirish
# Processing Record 41 of Set 2 | liku
# Processing Record 42 of Set 2 | saint george
# Processing Record 43 of Set 2 | malakal
# Processing Record 44 of Set 2 | arrecife
# Processing Record 45 of Set 2 | tilichiki
# Processing Record 46 of Set 2 | roald
# Processing Record 47 of Set 2 | norman wells
# Processing Record 48 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 49 of Set 2 | nikolskoye
# Processing Record 50 of Set 2 | ribeira grande
# Processing Record 1 of Set 3 | lesnoye
# Processing Record 2 of Set 3 | carnarvon
# Processing Record 3 of Set 3 | barawe
# City not found. Skipping...
# Processing Record 4 of Set 3 | puerto ayora
# Processing Record 5 of Set 3 | souillac
# Processing Record 6 of Set 3 | port hardy
# Processing Record 7 of Set 3 | thompson
# Processing Record 8 of Set 3 | batemans bay
# Processing Record 9 of Set 3 | mar del plata
# Processing Record 10 of Set 3 | meyungs
# City not found. Skipping...
# Processing Record 11 of Set 3 | hobart
# Processing Record 12 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 13 of Set 3 | torbay
# Processing Record 14 of Set 3 | cape town
# Processing Record 15 of Set 3 | provideniya
# Processing Record 16 of Set 3 | ambilobe
# Processing Record 17 of Set 3 | macomer
# Processing Record 18 of Set 3 | busselton
# Processing Record 19 of Set 3 | kaitangata
# Processing Record 20 of Set 3 | esperance
# Processing Record 21 of Set 3 | chiusi
# Processing Record 22 of Set 3 | vadso
# Processing Record 23 of Set 3 | mugango
# Processing Record 24 of Set 3 | saskylakh
# Processing Record 25 of Set 3 | sao mateus
# Processing Record 26 of Set 3 | cabo san lucas
# Processing Record 27 of Set 3 | guerrero negro
# Processing Record 28 of Set 3 | cururupu
# Processing Record 29 of Set 3 | seoul
# Processing Record 30 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 31 of Set 3 | windhoek
# Processing Record 32 of Set 3 | pailon
# Processing Record 33 of Set 3 | geraldton
# Processing Record 34 of Set 3 | carutapera
# Processing Record 35 of Set 3 | kodiak
# Processing Record 36 of Set 3 | bredasdorp
# Processing Record 37 of Set 3 | port elizabeth
# Processing Record 38 of Set 3 | lasa
# Processing Record 39 of Set 3 | horta
# Processing Record 40 of Set 3 | hasaki
# Processing Record 41 of Set 3 | zaltan
# Processing Record 42 of Set 3 | padang
# Processing Record 43 of Set 3 | abu samrah
# Processing Record 44 of Set 3 | kouroussa
# Processing Record 45 of Set 3 | avarua
# Processing Record 46 of Set 3 | mahebourg
# Processing Record 47 of Set 3 | garowe
# Processing Record 48 of Set 3 | nassjo
# Processing Record 49 of Set 3 | hithadhoo
# Processing Record 50 of Set 3 | spasskoye
# Processing Record 1 of Set 4 | sorland
# Processing Record 2 of Set 4 | bage
# Processing Record 3 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 4 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 5 of Set 4 | yeppoon
# Processing Record 6 of Set 4 | naze
# Processing Record 7 of Set 4 | shenxian
# Processing Record 8 of Set 4 | taltal
# Processing Record 9 of Set 4 | sinnamary
# Processing Record 10 of Set 4 | ostrovnoy
# Processing Record 11 of Set 4 | new norfolk
# Processing Record 12 of Set 4 | zhezkazgan
# Processing Record 13 of Set 4 | rocha
# Processing Record 14 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 15 of Set 4 | tiksi
# Processing Record 16 of Set 4 | north branch
# Processing Record 17 of Set 4 | thunder bay
# Processing Record 18 of Set 4 | la puebla del rio
# Processing Record 19 of Set 4 | moratuwa
# Processing Record 20 of Set 4 | tommot
# Processing Record 21 of Set 4 | dryden
# Processing Record 22 of Set 4 | san patricio
# Processing Record 23 of Set 4 | ponta delgada
# Processing Record 24 of Set 4 | skjervoy
# Processing Record 25 of Set 4 | zhanaozen
# Processing Record 26 of Set 4 | hofn
# Processing Record 27 of Set 4 | oneonta
# Processing Record 28 of Set 4 | tura
# Processing Record 29 of Set 4 | guatire
# Processing Record 30 of Set 4 | omsk
# Processing Record 31 of Set 4 | tucumcari
# Processing Record 32 of Set 4 | montbrison
# Processing Record 33 of Set 4 | catemaco
# Processing Record 34 of Set 4 | romitan
# Processing Record 35 of Set 4 | sao filipe
# Processing Record 36 of Set 4 | mao
# Processing Record 37 of Set 4 | zhuozhou
# City not found. Skipping...
# Processing Record 38 of Set 4 | longyearbyen
# Processing Record 39 of Set 4 | clyde river
# Processing Record 40 of Set 4 | nyurba
# Processing Record 41 of Set 4 | varhaug
# Processing Record 42 of Set 4 | sola
# Processing Record 43 of Set 4 | rungata
# City not found. Skipping...
# Processing Record 44 of Set 4 | quatre cocos
# Processing Record 45 of Set 4 | velingara
# Processing Record 46 of Set 4 | acari
# Processing Record 47 of Set 4 | son la
# Processing Record 48 of Set 4 | mayo
# Processing Record 49 of Set 4 | ahipara
# Processing Record 50 of Set 4 | swan river
# Processing Record 1 of Set 5 | nuevo progreso
# Processing Record 2 of Set 5 | khatanga
# Processing Record 3 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 4 of Set 5 | larsnes
# Processing Record 5 of Set 5 | vila velha
# Processing Record 6 of Set 5 | upernavik
# Processing Record 7 of Set 5 | dakar
# Processing Record 8 of Set 5 | trelew
# Processing Record 9 of Set 5 | mocambique
# City not found. Skipping...
# Processing Record 10 of Set 5 | guiratinga
# Processing Record 11 of Set 5 | nysa
# Processing Record 12 of Set 5 | tukrah
# Processing Record 13 of Set 5 | saldanha
# Processing Record 14 of Set 5 | kisiwani
# Processing Record 15 of Set 5 | ilulissat
# Processing Record 16 of Set 5 | berdigestyakh
# Processing Record 17 of Set 5 | tuatapere
# Processing Record 18 of Set 5 | sangre grande
# Processing Record 19 of Set 5 | kavieng
# Processing Record 20 of Set 5 | launceston
# Processing Record 21 of Set 5 | conceicao do araguaia
# Processing Record 22 of Set 5 | grootfontein
# Processing Record 23 of Set 5 | sackville
# Processing Record 24 of Set 5 | yambio
# Processing Record 25 of Set 5 | salalah
# Processing Record 26 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 27 of Set 5 | nome
# Processing Record 28 of Set 5 | sedelnikovo
# City not found. Skipping...
# Processing Record 29 of Set 5 | kentau
# Processing Record 30 of Set 5 | juifang
# City not found. Skipping...
# Processing Record 31 of Set 5 | atima
# Processing Record 32 of Set 5 | owerri
# Processing Record 33 of Set 5 | sao felipe
# Processing Record 34 of Set 5 | leningradskiy
# Processing Record 35 of Set 5 | gurgan
# City not found. Skipping...
# Processing Record 36 of Set 5 | cerritos
# Processing Record 37 of Set 5 | abashiri
# Processing Record 38 of Set 5 | wulanhaote
# City not found. Skipping...
# Processing Record 39 of Set 5 | nurota
# Processing Record 40 of Set 5 | manaure
# Processing Record 41 of Set 5 | kaeo
# Processing Record 42 of Set 5 | brownsville
# Processing Record 43 of Set 5 | yenagoa
# Processing Record 44 of Set 5 | georgetown
# Processing Record 45 of Set 5 | kangaatsiaq
# Processing Record 46 of Set 5 | guanambi
# Processing Record 47 of Set 5 | povenets
# Processing Record 48 of Set 5 | sao sepe
# Processing Record 49 of Set 5 | vila franca do campo
# Processing Record 50 of Set 5 | adrar
# Processing Record 1 of Set 6 | kurunegala
# Processing Record 2 of Set 6 | mahanoro
# Processing Record 3 of Set 6 | iqaluit
# Processing Record 4 of Set 6 | anadyr
# Processing Record 5 of Set 6 | nemuro
# Processing Record 6 of Set 6 | wewak
# Processing Record 7 of Set 6 | mogadishu
# Processing Record 8 of Set 6 | mattru
# Processing Record 9 of Set 6 | januaria
# Processing Record 10 of Set 6 | iberia
# Processing Record 11 of Set 6 | mangai
# Processing Record 12 of Set 6 | port-gentil
# Processing Record 13 of Set 6 | berlevag
# Processing Record 14 of Set 6 | lahat
# Processing Record 15 of Set 6 | adre
# Processing Record 16 of Set 6 | broome
# Processing Record 17 of Set 6 | iquitos
# Processing Record 18 of Set 6 | alofi
# Processing Record 19 of Set 6 | mandera
# Processing Record 20 of Set 6 | yithion
# City not found. Skipping...
# Processing Record 21 of Set 6 | talnakh
# Processing Record 22 of Set 6 | peace river
# Processing Record 23 of Set 6 | kushima
# Processing Record 24 of Set 6 | yining
# Processing Record 25 of Set 6 | castro
# Processing Record 26 of Set 6 | sorong
# Processing Record 27 of Set 6 | bonthe
# Processing Record 28 of Set 6 | burns lake
# Processing Record 29 of Set 6 | tiarei
# Processing Record 30 of Set 6 | louisbourg
# City not found. Skipping...
# Processing Record 31 of Set 6 | pangai
# Processing Record 32 of Set 6 | chapais
# Processing Record 33 of Set 6 | paita
# Processing Record 34 of Set 6 | north bend
# Processing Record 35 of Set 6 | axim
# Processing Record 36 of Set 6 | manturovo
# Processing Record 37 of Set 6 | svetlaya
# Processing Record 38 of Set 6 | gisborne
# Processing Record 39 of Set 6 | chuy
# Processing Record 40 of Set 6 | havelock
# Processing Record 41 of Set 6 | dandong
# Processing Record 42 of Set 6 | azare
# Processing Record 43 of Set 6 | mehriz
# Processing Record 44 of Set 6 | isabela
# Processing Record 45 of Set 6 | codrington
# Processing Record 46 of Set 6 | maumelle
# Processing Record 47 of Set 6 | guarapari
# Processing Record 48 of Set 6 | rolim de moura
# City not found. Skipping...
# Processing Record 49 of Set 6 | el alto
# Processing Record 50 of Set 6 | northampton
# Processing Record 1 of Set 7 | porto walter
# Processing Record 2 of Set 7 | gushikawa
# Processing Record 3 of Set 7 | matagami
# Processing Record 4 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 5 of Set 7 | pevek
# Processing Record 6 of Set 7 | bambous virieux
# Processing Record 7 of Set 7 | bethel
# Processing Record 8 of Set 7 | anito
# Processing Record 9 of Set 7 | zhitikara
# City not found. Skipping...
# Processing Record 10 of Set 7 | arraial do cabo
# Processing Record 11 of Set 7 | hilo
# Processing Record 12 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 13 of Set 7 | te anau
# Processing Record 14 of Set 7 | kolokani
# Processing Record 15 of Set 7 | bumba
# Processing Record 16 of Set 7 | kisangani
# Processing Record 17 of Set 7 | maxixe
# Processing Record 18 of Set 7 | bone
# Processing Record 19 of Set 7 | pechenga
# Processing Record 20 of Set 7 | saint-joseph
# Processing Record 21 of Set 7 | waiouru
# Processing Record 22 of Set 7 | rypefjord
# Processing Record 23 of Set 7 | hoi an
# Processing Record 24 of Set 7 | varkaus
# Processing Record 25 of Set 7 | kamenka
# Processing Record 26 of Set 7 | evensk
# Processing Record 27 of Set 7 | poya
# Processing Record 28 of Set 7 | umm lajj
# Processing Record 29 of Set 7 | vitry-le-francois
# Processing Record 30 of Set 7 | lahan
# Processing Record 31 of Set 7 | klaeng
# Processing Record 32 of Set 7 | cozumel
# Processing Record 33 of Set 7 | roseburg
# Processing Record 34 of Set 7 | kirakira
# Processing Record 35 of Set 7 | hamilton
# Processing Record 36 of Set 7 | jahrom
# City not found. Skipping...
# Processing Record 37 of Set 7 | calderitas
# Processing Record 38 of Set 7 | klaksvik
# Processing Record 39 of Set 7 | halifax
# Processing Record 40 of Set 7 | manama
# Processing Record 41 of Set 7 | kenai
# Processing Record 42 of Set 7 | tocopilla
# Processing Record 43 of Set 7 | flinders
# Processing Record 44 of Set 7 | mossendjo
# Processing Record 45 of Set 7 | faanui
# Processing Record 46 of Set 7 | polunochnoye
# Processing Record 47 of Set 7 | cascavel
# Processing Record 48 of Set 7 | sangueya
# Processing Record 49 of Set 7 | birin
# Processing Record 50 of Set 7 | viransehir
# Processing Record 1 of Set 8 | richards bay
# Processing Record 2 of Set 8 | ardakan
# Processing Record 3 of Set 8 | pampierstad
# Processing Record 4 of Set 8 | pingliang
# Processing Record 5 of Set 8 | aleysk
# Processing Record 6 of Set 8 | andenes
# Processing Record 7 of Set 8 | chervone
# Processing Record 8 of Set 8 | haines junction
# Processing Record 9 of Set 8 | ambon
# Processing Record 10 of Set 8 | cockburn town
# Processing Record 11 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 12 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 13 of Set 8 | nizhnevartovsk
# Processing Record 14 of Set 8 | toora-khem
# Processing Record 15 of Set 8 | manakara
# Processing Record 16 of Set 8 | eganville
# Processing Record 17 of Set 8 | sao joaquim
# Processing Record 18 of Set 8 | araouane
# Processing Record 19 of Set 8 | wagar
# Processing Record 20 of Set 8 | mohacs
# Processing Record 21 of Set 8 | hualmay
# Processing Record 22 of Set 8 | batagay
# Processing Record 23 of Set 8 | rio grande
# Processing Record 24 of Set 8 | chandbali
# Processing Record 25 of Set 8 | jawhar
# Processing Record 26 of Set 8 | walvis bay
# Processing Record 27 of Set 8 | bengkulu
# Processing Record 28 of Set 8 | rawson
# Processing Record 29 of Set 8 | ketchikan
# Processing Record 30 of Set 8 | beringovskiy
# Processing Record 31 of Set 8 | lavrentiya
# Processing Record 32 of Set 8 | phan rang
# City not found. Skipping...
# Processing Record 33 of Set 8 | arlit
# Processing Record 34 of Set 8 | samalaeulu
# City not found. Skipping...
# Processing Record 35 of Set 8 | livingstone
# Processing Record 36 of Set 8 | labuhan
# Processing Record 37 of Set 8 | portoferraio
# Processing Record 38 of Set 8 | bardiyah
# Processing Record 39 of Set 8 | baykit
# Processing Record 40 of Set 8 | muroto
# Processing Record 41 of Set 8 | balakliya
# Processing Record 42 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 43 of Set 8 | saint-junien
# Processing Record 44 of Set 8 | ahmadnagar
# Processing Record 45 of Set 8 | maniitsoq
# Processing Record 46 of Set 8 | marsa matruh
# Processing Record 47 of Set 8 | kemijarvi
# Processing Record 48 of Set 8 | byron bay
# Processing Record 49 of Set 8 | asau
# Processing Record 50 of Set 8 | bambanglipuro
# Processing Record 1 of Set 9 | grindavik
# Processing Record 2 of Set 9 | tuensang
# Processing Record 3 of Set 9 | hit
# Processing Record 4 of Set 9 | spring valley
# Processing Record 5 of Set 9 | cherskiy
# Processing Record 6 of Set 9 | terra roxa
# Processing Record 7 of Set 9 | yar-sale
# Processing Record 8 of Set 9 | phan thiet
# Processing Record 9 of Set 9 | hami
# Processing Record 10 of Set 9 | songjianghe
# Processing Record 11 of Set 9 | russell
# Processing Record 12 of Set 9 | kampot
# Processing Record 13 of Set 9 | nantucket
# Processing Record 14 of Set 9 | palana
# Processing Record 15 of Set 9 | talara
# Processing Record 16 of Set 9 | aklavik
# Processing Record 17 of Set 9 | doume
# Processing Record 18 of Set 9 | tsuruga
# Processing Record 19 of Set 9 | gorin
# Processing Record 20 of Set 9 | bontang
# Processing Record 21 of Set 9 | college
# Processing Record 22 of Set 9 | bom despacho
# Processing Record 23 of Set 9 | port blair
# Processing Record 24 of Set 9 | port shepstone
# Processing Record 25 of Set 9 | marang
# Processing Record 26 of Set 9 | okakarara
# Processing Record 27 of Set 9 | sakakah
# Processing Record 28 of Set 9 | talcahuano
# Processing Record 29 of Set 9 | parakou
# Processing Record 30 of Set 9 | los llanos de aridane
# Processing Record 31 of Set 9 | verkhnevilyuysk
# Processing Record 32 of Set 9 | lorengau
# Processing Record 33 of Set 9 | maghama
# City not found. Skipping...
# Processing Record 34 of Set 9 | vientiane
# Processing Record 35 of Set 9 | the pas
# Processing Record 36 of Set 9 | cintalapa
# Processing Record 37 of Set 9 | ginir
# Processing Record 38 of Set 9 | maputo
# Processing Record 39 of Set 9 | port macquarie
# Processing Record 40 of Set 9 | panormos
# Processing Record 41 of Set 9 | belaya gora
# Processing Record 42 of Set 9 | akyab
# Processing Record 43 of Set 9 | pangnirtung
# Processing Record 44 of Set 9 | jalu
# Processing Record 45 of Set 9 | saint-imier
# Processing Record 46 of Set 9 | irawan
# Processing Record 47 of Set 9 | dobrokoz
# Processing Record 48 of Set 9 | pacific grove
# Processing Record 49 of Set 9 | kamaishi
# Processing Record 50 of Set 9 | poronaysk
# Processing Record 1 of Set 10 | kiama
# Processing Record 2 of Set 10 | boguchany
# Processing Record 3 of Set 10 | guangyuan
# Processing Record 4 of Set 10 | altay
# Processing Record 5 of Set 10 | wajima
# Processing Record 6 of Set 10 | tornio
# Processing Record 7 of Set 10 | jati
# Processing Record 8 of Set 10 | mandalgovi
# Processing Record 9 of Set 10 | sitka
# Processing Record 10 of Set 10 | puerto escondido
# Processing Record 11 of Set 10 | sorvag
# City not found. Skipping...
# Processing Record 12 of Set 10 | srandakan
# Processing Record 13 of Set 10 | skibbereen
# Processing Record 14 of Set 10 | tailai
# Processing Record 15 of Set 10 | mackay
# Processing Record 16 of Set 10 | dali
# Processing Record 17 of Set 10 | usinsk
# Processing Record 18 of Set 10 | bilibino
# Processing Record 19 of Set 10 | saint anthony
# Processing Record 20 of Set 10 | taoudenni
# Processing Record 21 of Set 10 | rosarito
# Processing Record 22 of Set 10 | tromso
# Processing Record 23 of Set 10 | poum
# Processing Record 24 of Set 10 | dawei
# Processing Record 25 of Set 10 | biak
# Processing Record 26 of Set 10 | severo-kurilsk
# Processing Record 27 of Set 10 | sisimiut
# Processing Record 28 of Set 10 | saharsa
# Processing Record 29 of Set 10 | vigrestad
# Processing Record 30 of Set 10 | vestmannaeyjar
# Processing Record 31 of Set 10 | turka
# Processing Record 32 of Set 10 | kollumerland
# City not found. Skipping...
# Processing Record 33 of Set 10 | charagua
# Processing Record 34 of Set 10 | mount isa
# Processing Record 35 of Set 10 | funadhoo
# Processing Record 36 of Set 10 | katsuura
# Processing Record 37 of Set 10 | siniscola
# Processing Record 38 of Set 10 | marawi
# Processing Record 39 of Set 10 | monte gordo
# Processing Record 40 of Set 10 | sarangani
# Processing Record 41 of Set 10 | pringsewu
# Processing Record 42 of Set 10 | hobyo
# Processing Record 43 of Set 10 | cabedelo
# Processing Record 44 of Set 10 | grand gaube
# Processing Record 45 of Set 10 | toungoo
# City not found. Skipping...
# Processing Record 46 of Set 10 | keti bandar
# Processing Record 47 of Set 10 | svetlyy
# Processing Record 48 of Set 10 | isangel
# Processing Record 49 of Set 10 | bandar
# Processing Record 50 of Set 10 | safaqis
# City not found. Skipping...
# Processing Record 1 of Set 11 | san ramon
# Processing Record 2 of Set 11 | bubaque
# Processing Record 3 of Set 11 | biskamzha
# Processing Record 4 of Set 11 | ust-omchug
# Processing Record 5 of Set 11 | izumo
# Processing Record 6 of Set 11 | necochea
# Processing Record 7 of Set 11 | ayagoz
# Processing Record 8 of Set 11 | arrifes
# Processing Record 9 of Set 11 | hokitika
# Processing Record 10 of Set 11 | paradwip
# City not found. Skipping...
# Processing Record 11 of Set 11 | mayumba
# Processing Record 12 of Set 11 | calafell
# Processing Record 13 of Set 11 | areosa
# Processing Record 14 of Set 11 | laguna
# Processing Record 15 of Set 11 | tuscaloosa
# Processing Record 16 of Set 11 | alta floresta
# Processing Record 17 of Set 11 | coihaique
# Processing Record 18 of Set 11 | turayf
# Processing Record 19 of Set 11 | puerto cabezas
# Processing Record 20 of Set 11 | atasu
# Processing Record 21 of Set 11 | uri
# Processing Record 22 of Set 11 | viligili
# City not found. Skipping...
# Processing Record 23 of Set 11 | buala
# Processing Record 24 of Set 11 | nelson bay
# Processing Record 25 of Set 11 | carmen
# Processing Record 26 of Set 11 | aparecida do taboado
# Processing Record 27 of Set 11 | dingle
# Processing Record 28 of Set 11 | dzilam gonzalez
# Processing Record 29 of Set 11 | verkhnyaya inta
# Processing Record 30 of Set 11 | makakilo city
# Processing Record 31 of Set 11 | dalian
# Processing Record 32 of Set 11 | kushikino
# Processing Record 33 of Set 11 | puqi
# Processing Record 34 of Set 11 | bousse
# Processing Record 35 of Set 11 | taga
# Processing Record 36 of Set 11 | scottsburgh
# City not found. Skipping...
# Processing Record 37 of Set 11 | bar harbor
# Processing Record 38 of Set 11 | shubarshi
# Processing Record 39 of Set 11 | inongo
# Processing Record 40 of Set 11 | omboue
# Processing Record 41 of Set 11 | veraval
# Processing Record 42 of Set 11 | juneau
# Processing Record 43 of Set 11 | bur gabo
# City not found. Skipping...
# Processing Record 44 of Set 11 | tubruq
# City not found. Skipping...
# Processing Record 45 of Set 11 | churapcha
# Processing Record 46 of Set 11 | stornoway
# Processing Record 47 of Set 11 | puerto plata
# Processing Record 48 of Set 11 | san cristobal
# Processing Record 49 of Set 11 | tautira
# Processing Record 50 of Set 11 | pandan
# Processing Record 1 of Set 12 | ruatoria
# City not found. Skipping...
# Processing Record 2 of Set 12 | yershov
# Processing Record 3 of Set 12 | asuncion
# Processing Record 4 of Set 12 | kahului
# Processing Record 5 of Set 12 | fallon
# Processing Record 6 of Set 12 | keita
# Processing Record 7 of Set 12 | cap malheureux
# Processing Record 8 of Set 12 | autazes
# Processing Record 9 of Set 12 | egvekinot
# Processing Record 10 of Set 12 | bilma
# Processing Record 11 of Set 12 | south lake tahoe
# Processing Record 12 of Set 12 | gudari
# Processing Record 13 of Set 12 | igarka
# Processing Record 14 of Set 12 | la sarre
# Processing Record 15 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 16 of Set 12 | rodrigues alves
# Processing Record 17 of Set 12 | bakel
# Processing Record 18 of Set 12 | sataua
# City not found. Skipping...
# Processing Record 19 of Set 12 | piacabucu
# Processing Record 20 of Set 12 | peterhead
# Processing Record 21 of Set 12 | kayerkan
# Processing Record 22 of Set 12 | juelsminde
# Processing Record 23 of Set 12 | menongue
# Processing Record 24 of Set 12 | puerto colombia
# Processing Record 25 of Set 12 | marrakesh
# Processing Record 26 of Set 12 | benguela
# Processing Record 27 of Set 12 | iracoubo
# Processing Record 28 of Set 12 | taywarah
# Processing Record 29 of Set 12 | alice springs
# Processing Record 30 of Set 12 | nizhniy odes
# Processing Record 31 of Set 12 | jumla
# Processing Record 32 of Set 12 | sept-iles
# Processing Record 33 of Set 12 | jablunkov
# Processing Record 34 of Set 12 | coahuayana
# Processing Record 35 of Set 12 | vilyuysk
# Processing Record 36 of Set 12 | lata
# Processing Record 37 of Set 12 | hun
# Processing Record 38 of Set 12 | sakassou
# Processing Record 39 of Set 12 | inhambane
# Processing Record 40 of Set 12 | coalcoman
# City not found. Skipping...
# Processing Record 41 of Set 12 | villa de san antonio
# Processing Record 42 of Set 12 | merauke
# Processing Record 43 of Set 12 | envira
# Processing Record 44 of Set 12 | lamar
# Processing Record 45 of Set 12 | altamont
# Processing Record 46 of Set 12 | mount gambier
# Processing Record 47 of Set 12 | port hope
# Processing Record 48 of Set 12 | kidal
# Processing Record 49 of Set 12 | brainerd
# Processing Record 50 of Set 12 | gimli
# Processing Record 1 of Set 13 | nacala
# Processing Record 2 of Set 13 | kralendijk
# Processing Record 3 of Set 13 | zeya
# Processing Record 4 of Set 13 | mendeleyevo
# Processing Record 5 of Set 13 | nelson
# Processing Record 6 of Set 13 | santarem
# Processing Record 7 of Set 13 | nouadhibou
# Processing Record 8 of Set 13 | vestmanna
# Processing Record 9 of Set 13 | deputatskiy
# Processing Record 10 of Set 13 | toliary
# City not found. Skipping...
# Processing Record 11 of Set 13 | san andres
# Processing Record 12 of Set 13 | brae
# Processing Record 13 of Set 13 | gazojak
# Processing Record 14 of Set 13 | cairns
# Processing Record 15 of Set 13 | kadykchan
# City not found. Skipping...
# Processing Record 16 of Set 13 | aitape
# Processing Record 17 of Set 13 | fortuna
# Processing Record 18 of Set 13 | fowa
# Processing Record 19 of Set 13 | sistranda
# Processing Record 20 of Set 13 | steamboat springs
# Processing Record 21 of Set 13 | lamu
# Processing Record 22 of Set 13 | esmeralda
# Processing Record 23 of Set 13 | khandyga
# Processing Record 24 of Set 13 | deneysville
# Processing Record 25 of Set 13 | kargasok
# Processing Record 26 of Set 13 | panaba
# Processing Record 27 of Set 13 | zhigansk
# Processing Record 28 of Set 13 | libourne
# Processing Record 29 of Set 13 | plettenberg bay
# Processing Record 30 of Set 13 | kharan
# Processing Record 31 of Set 13 | impfondo
# Processing Record 32 of Set 13 | tadine
# Processing Record 33 of Set 13 | petropavlovsk-kamchatskiy
# Processing Record 34 of Set 13 | marsh harbour
# Processing Record 35 of Set 13 | narrabri
# Processing Record 36 of Set 13 | west bay
# Processing Record 37 of Set 13 | mantua
# Processing Record 38 of Set 13 | surman
# Processing Record 39 of Set 13 | kapit
# Processing Record 40 of Set 13 | caranan
# Processing Record 41 of Set 13 | raisio
# Processing Record 42 of Set 13 | nizhniy kuranakh
# Processing Record 43 of Set 13 | ola
# Processing Record 44 of Set 13 | santa maria
# Processing Record 45 of Set 13 | bathsheba
# Processing Record 46 of Set 13 | halalo
# City not found. Skipping...
# Processing Record 47 of Set 13 | angoche
# Processing Record 48 of Set 13 | vila
# Processing Record 49 of Set 13 | qaqortoq
# Processing Record 50 of Set 13 | linda
# Processing Record 1 of Set 14 | pafos
# Processing Record 2 of Set 14 | aksu
# Processing Record 3 of Set 14 | port lincoln
# Processing Record 4 of Set 14 | sobolevo
# Processing Record 5 of Set 14 | gulu
# Processing Record 6 of Set 14 | aqtobe
# Processing Record 7 of Set 14 | kaposmero
# Processing Record 8 of Set 14 | fairbanks
# Processing Record 9 of Set 14 | kamenskoye
# City not found. Skipping...
# Processing Record 10 of Set 14 | itarema
# Processing Record 11 of Set 14 | espanola
# Processing Record 12 of Set 14 | harper
# Processing Record 13 of Set 14 | meulaboh
# Processing Record 14 of Set 14 | aksarka
# Processing Record 15 of Set 14 | mangrol
# Processing Record 16 of Set 14 | neiafu
# Processing Record 17 of Set 14 | rameswaram
# Processing Record 18 of Set 14 | presidencia roque saenz pena
# Processing Record 19 of Set 14 | ibadan
# Processing Record 20 of Set 14 | kotido
# Processing Record 21 of Set 14 | san antero
# Processing Record 22 of Set 14 | jiazi
# Processing Record 23 of Set 14 | lushunkou
# City not found. Skipping...
# Processing Record 24 of Set 14 | borovichi
# Processing Record 25 of Set 14 | nanortalik
# Processing Record 26 of Set 14 | mahibadhoo
# Processing Record 27 of Set 14 | araripe
# Processing Record 28 of Set 14 | wad rawah
# Processing Record 29 of Set 14 | daurala
# Processing Record 30 of Set 14 | bath
# Processing Record 31 of Set 14 | edson
# Processing Record 32 of Set 14 | lolua
# City not found. Skipping...
# Processing Record 33 of Set 14 | puri
# Processing Record 34 of Set 14 | sao joao da barra
# Processing Record 35 of Set 14 | atar
# Processing Record 36 of Set 14 | vagur
# Processing Record 37 of Set 14 | leeton
# Processing Record 38 of Set 14 | okhotsk
# Processing Record 39 of Set 14 | huilong
# Processing Record 40 of Set 14 | mihijam
# Processing Record 41 of Set 14 | jaisalmer
# Processing Record 42 of Set 14 | pondicherry
# Processing Record 43 of Set 14 | ankang
# Processing Record 44 of Set 14 | fort nelson
# Processing Record 45 of Set 14 | yerbogachen
# Processing Record 46 of Set 14 | shchelyayur
# City not found. Skipping...
# Processing Record 47 of Set 14 | coquimbo
# Processing Record 48 of Set 14 | goderich
# Processing Record 49 of Set 14 | malwan
# City not found. Skipping...
# Processing Record 50 of Set 14 | korla
# Processing Record 1 of Set 15 | samarai
# Processing Record 2 of Set 15 | waingapu
# Processing Record 3 of Set 15 | elko
# Processing Record 4 of Set 15 | nuuk
# Processing Record 5 of Set 15 | bandundu
# Processing Record 6 of Set 15 | visnes
# Processing Record 7 of Set 15 | chimbote
# Processing Record 8 of Set 15 | novozavedennoye
# Processing Record 9 of Set 15 | bargal
# City not found. Skipping...
# Processing Record 10 of Set 15 | timra
# Processing Record 11 of Set 15 | banjar
# Processing Record 12 of Set 15 | srednekolymsk
# Processing Record 13 of Set 15 | moron
# Processing Record 14 of Set 15 | la asuncion
# Processing Record 15 of Set 15 | ahuimanu
# Processing Record 16 of Set 15 | kastamonu
# Processing Record 17 of Set 15 | kasongo-lunda
# Processing Record 18 of Set 15 | lincoln
# Processing Record 19 of Set 15 | longhua
# Processing Record 20 of Set 15 | yichang
# Processing Record 21 of Set 15 | sabha
# Processing Record 22 of Set 15 | urussu
# Processing Record 23 of Set 15 | vanavara
# Processing Record 24 of Set 15 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 25 of Set 15 | bud
# Processing Record 26 of Set 15 | hailar
# Processing Record 27 of Set 15 | san policarpo
# Processing Record 28 of Set 15 | gat
# Processing Record 29 of Set 15 | springdale
# Processing Record 30 of Set 15 | mahuva
# Processing Record 31 of Set 15 | tual
# Processing Record 32 of Set 15 | nibbar
# Processing Record 33 of Set 15 | serik
# Processing Record 34 of Set 15 | wschowa
# Processing Record 35 of Set 15 | lugovoy
# Processing Record 36 of Set 15 | santa ines
# Processing Record 37 of Set 15 | mandello del lario
# Processing Record 38 of Set 15 | ballina
# Processing Record 39 of Set 15 | barabai
# Processing Record 40 of Set 15 | comodoro rivadavia
# Processing Record 41 of Set 15 | san rafael
# Processing Record 42 of Set 15 | noumea
# Processing Record 43 of Set 15 | sindor
# Processing Record 44 of Set 15 | boa vista
# Processing Record 45 of Set 15 | ziarat
# Processing Record 46 of Set 15 | makungu
# Processing Record 47 of Set 15 | ucluelet
# Processing Record 48 of Set 15 | beliator
# Processing Record 49 of Set 15 | marienburg
# Processing Record 50 of Set 15 | tartus
# Processing Record 1 of Set 16 | tuggurt
# City not found. Skipping...
# Processing Record 2 of Set 16 | novochernorechenskiy
# Processing Record 3 of Set 16 | rawannawi
# City not found. Skipping...
# Processing Record 4 of Set 16 | tomatlan
# Processing Record 5 of Set 16 | blyznyuky
# Processing Record 6 of Set 16 | morant bay
# Processing Record 7 of Set 16 | havoysund
# Processing Record 8 of Set 16 | abu kamal
# Processing Record 9 of Set 16 | chunhuhub
# Processing Record 10 of Set 16 | kracheh
# City not found. Skipping...
# Processing Record 11 of Set 16 | quesnel
# Processing Record 12 of Set 16 | antalaha
# Processing Record 13 of Set 16 | matara
# Processing Record 14 of Set 16 | sampit
# Processing Record 15 of Set 16 | gamba
# Processing Record 16 of Set 16 | tutoia
# Processing Record 17 of Set 16 | yulara
# Processing Record 18 of Set 16 | prince rupert
# Processing Record 19 of Set 16 | camacha
# Processing Record 20 of Set 16 | mackenzie
# Processing Record 21 of Set 16 | aracati
# Processing Record 22 of Set 16 | huarmey
# Processing Record 23 of Set 16 | nedjo
# Processing Record 24 of Set 16 | newberg
# Processing Record 25 of Set 16 | gravdal
# Processing Record 26 of Set 16 | rajanpur
# Processing Record 27 of Set 16 | kazalinsk
# City not found. Skipping...
# Processing Record 28 of Set 16 | ossora
# Processing Record 29 of Set 16 | nileshwar
# Processing Record 30 of Set 16 | olinda
# Processing Record 31 of Set 16 | okato
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City Country                 Date      Lat       Lng  Max Temp  \
# 0         Tasiilaq      GL  2021-12-22 16:48:22  65.6145  -37.6368     30.36
# 1  Louis Trichardt      ZA  2021-12-22 16:48:23 -23.0439   29.9032     74.05
# 2     Ponta Do Sol      PT  2021-12-22 16:48:23  32.6667  -17.1000     72.72
# 3        Manzhouli      CN  2021-12-22 16:48:24  49.6000  117.4333    -16.44
# 4            Lagoa      PT  2021-12-22 16:48:24  39.0500  -27.9833     59.94
# 5         Brewster      US  2021-12-22 16:48:24  41.3973  -73.6171     45.82
# 6            Avera      US  2021-12-22 16:48:25  33.1940  -82.5271     53.74
# 7     Anuradhapura      LK  2021-12-22 16:48:25   8.3565   80.4173     70.16
# 8           Vagamo      NO  2021-12-22 16:48:26  61.8751    9.0967      9.27
# 9           Trairi      BR  2021-12-22 16:45:36  -3.2778  -39.2689     87.85
#
#    Humidity  Cloudiness  Wind Speed Current Description
# 0        54           2        5.08           clear sky
# 1        62          94        5.08     overcast clouds
# 2        84          18        8.30          few clouds
# 3        90           8        4.36           clear sky
# 4        61          78       30.13       broken clouds
# 5        76           1        3.00           clear sky
# 6        56          18       11.61          few clouds
# 7        90          50        4.92    scattered clouds
# 8        96          99        2.04          light snow
# 9        58          25       14.45    scattered clouds

# %%
new_column_order = ["City", "Country", "Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed", "Current Description"]
reordered_city_data_df = city_data_df[new_column_order]
reordered_city_data_df.head()
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Tasiilaq      GL  65.6145  -37.6368     30.36        54           2
# 1  Louis Trichardt      ZA -23.0439   29.9032     74.05        62          94
# 2     Ponta Do Sol      PT  32.6667  -17.1000     72.72        84          18
# 3        Manzhouli      CN  49.6000  117.4333    -16.44        90           8
# 4            Lagoa      PT  39.0500  -27.9833     59.94        61          78
#
#    Wind Speed Current Description
# 0        5.08           clear sky
# 1        5.08     overcast clouds
# 2        8.30          few clouds
# 3        4.36           clear sky
# 4       30.13       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/cities.csv"
# Export the City_Data into a CSV.
reordered_city_data_df.to_csv(output_data_file, index_label="City_ID")
